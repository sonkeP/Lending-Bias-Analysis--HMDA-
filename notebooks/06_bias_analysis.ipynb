# %%
import pandas as pd
import numpy as np

agg = pd.read_parquet(
    "../data/analytics/hmda/agg_gender_income_state_purpose.parquet"
)

agg.head()
# Out:
#   state_code income_bucket loan_purpose applicant_gender  applications  \
# 0         CT        Middle            1             Male         11808
# 1         TX           Low           32           Female         11683
# 2         WA        Middle            1           Female         16383
# 3         WA        Middle            1             Male         25964
# 4         WA           Low           32             Male          3794
#
#    approvals  approval_rate  median_loan_amount
# 0       8579       0.726541            275000.0
# 1       4847       0.414876            125000.0
# 2      11975       0.730941            365000.0
# 3      18719       0.720960            395000.0
# 4       1475       0.388772            205000.0

# %%
pivot = (
    agg
    .pivot_table(
        index=["state_code", "income_bucket", "loan_purpose"],
        columns="applicant_gender",
        values=["applications", "approvals", "approval_rate"]
    )
    .reset_index()
)

pivot.columns = ["_".join(col).strip("_") for col in pivot.columns]
pivot.head()
# Out:
#   state_code income_bucket loan_purpose  applications_Female  \
# 0         AK          High            1                926.0
# 1         AK          High            2                130.0
# 2         AK          High           31                 56.0
# 3         AK          High           32                113.0
# 4         AK          High            4                127.0
#
#    applications_Male  approval_rate_Female  approval_rate_Male  \
# 0             1950.0              0.749460            0.743590
# 1              223.0              0.523077            0.547085
# 2              123.0              0.517857            0.609756
# 3              349.0              0.460177            0.515759
# 4              308.0              0.456693            0.448052
#
#    approvals_Female  approvals_Male
# 0             694.0          1450.0
# 1              68.0           122.0
# 2              29.0            75.0
# 3              52.0           180.0
# 4              58.0           138.0

# %%
pivot["approval_gap_male_minus_female"] = (
    pivot["approval_rate_Male"] - pivot["approval_rate_Female"]
)

pivot[[
    "state_code",
    "income_bucket",
    "loan_purpose",
    "approval_gap_male_minus_female"
]].head()
# Out:
#   state_code income_bucket loan_purpose  approval_gap_male_minus_female
# 0         AK          High            1                       -0.005870
# 1         AK          High            2                        0.024008
# 2         AK          High           31                        0.091899
# 3         AK          High           32                        0.055582
# 4         AK          High            4                       -0.008641

# %%
pivot["disparate_impact"] = (
    pivot["approval_rate_Female"] / pivot["approval_rate_Male"]
)

pivot[[
    "state_code",
    "income_bucket",
    "loan_purpose",
    "disparate_impact"
]].head()
# Out:
#   state_code income_bucket loan_purpose  disparate_impact
# 0         AK          High            1          1.007895
# 1         AK          High            2          0.956116
# 2         AK          High           31          0.849286
# 3         AK          High           32          0.892232
# 4         AK          High            4          1.019286

# %%
reliable = pivot[
    (pivot["applications_Male"] >= 50) &
    (pivot["applications_Female"] >= 50)
].copy()

reliable.shape
# Out:
# (772, 11)

# %%
reliable.sort_values(
    by="approval_gap_male_minus_female",
    ascending=False
).head(10)[[
    "state_code",
    "income_bucket",
    "loan_purpose",
    "approval_gap_male_minus_female",
    "disparate_impact",
    "applications_Female",
    "applications_Male"
]]
# Out:
#     state_code income_bucket loan_purpose  approval_gap_male_minus_female  \
# 785         WY          High           31                        0.175159
# 386         MS          High            2                        0.162718
# 389         MS          High            4                        0.131444
# 237         IN          High           31                        0.114355
# 779         WV        Middle            2                        0.111744
# 432         ND          High           31                        0.110252
# 401         MT          High            2                        0.103884
# 285         LA           Low            1                        0.096870
# 282         LA          High           31                        0.095346
# 431         ND          High            2                        0.094872
#
#      disparate_impact  applications_Female  applications_Male
# 785          0.740566                 62.0              157.0
# 386          0.748444                252.0              824.0
# 389          0.797046                401.0             1385.0
# 237          0.848119                700.0             2477.0
# 779          0.803117                498.0             1110.0
# 432          0.865968                 73.0              248.0
# 401          0.855443                244.0              558.0
# 285          0.801248              16926.0            15072.0
# 282          0.874270                454.0             1978.0
# 431          0.886154                130.0              360.0

# %%
from scipy.stats import chi2_contingency

# %%
test_row = reliable.iloc[0]
test_row[[
    "state_code", "income_bucket", "loan_purpose",
    "applications_Female", "approvals_Female",
    "applications_Male", "approvals_Male"
]]
# Out:
# state_code                 AK
# income_bucket            High
# loan_purpose                1
# applications_Female     926.0
# approvals_Female        694.0
# applications_Male      1950.0
# approvals_Male         1450.0
# Name: 0, dtype: object

# %%
table = [
    [
        int(test_row["approvals_Female"]),
        int(test_row["applications_Female"] - test_row["approvals_Female"])
    ],
    [
        int(test_row["approvals_Male"]),
        int(test_row["applications_Male"] - test_row["approvals_Male"])
    ]
]

table
# Out:
# [[694, 232], [1450, 500]]

# %%
from scipy.stats import chi2_contingency

chi2, p_value, dof, expected = chi2_contingency(table)

chi2, p_value, dof
# Out:
# (np.float64(0.08518987803405201), np.float64(0.77038368877083), 1)

# %%
reliable.sort_values(
    by="approval_gap_male_minus_female",
    ascending=False
).head(1)
# Out:
#     state_code income_bucket loan_purpose  applications_Female  \
# 785         WY          High           31                 62.0
#
#      applications_Male  approval_rate_Female  approval_rate_Male  \
# 785              157.0                   0.5            0.675159
#
#      approvals_Female  approvals_Male  approval_gap_male_minus_female  \
# 785              31.0           106.0                        0.175159
#
#      disparate_impact
# 785          0.740566

# %%
table2 = [
    [
        int(31),                 # Female approved
        int(62 - 31)             # Female not approved
    ],
    [
        int(106),                # Male approved
        int(157 - 106)           # Male not approved
    ]
]

table2
# Out:
# [[31, 31], [106, 51]]

# %%
from scipy.stats import chi2_contingency

chi2_2, p_value_2, dof_2, expected_2 = chi2_contingency(table2)

chi2_2, p_value_2, dof_2
# Out:
# (np.float64(5.098142500336253), np.float64(0.023951479113269374), 1)

# %%
def chi_square_pvalue(row):
    table = [
        [
            row["approvals_Female"],
            row["applications_Female"] - row["approvals_Female"]
        ],
        [
            row["approvals_Male"],
            row["applications_Male"] - row["approvals_Male"]
        ]
    ]
    _, p_value, _, _ = chi2_contingency(table)
    return p_value

# %%
reliable["p_value"] = reliable.apply(chi_square_pvalue, axis=1)
reliable.head()
# Out:
#   state_code income_bucket loan_purpose  applications_Female  \
# 0         AK          High            1                926.0
# 1         AK          High            2                130.0
# 2         AK          High           31                 56.0
# 3         AK          High           32                113.0
# 4         AK          High            4                127.0
#
#    applications_Male  approval_rate_Female  approval_rate_Male  \
# 0             1950.0              0.749460            0.743590
# 1              223.0              0.523077            0.547085
# 2              123.0              0.517857            0.609756
# 3              349.0              0.460177            0.515759
# 4              308.0              0.456693            0.448052
#
#    approvals_Female  approvals_Male  approval_gap_male_minus_female  \
# 0             694.0          1450.0                       -0.005870
# 1              68.0           122.0                        0.024008
# 2              29.0            75.0                        0.091899
# 3              52.0           180.0                        0.055582
# 4              58.0           138.0                       -0.008641
#
#    disparate_impact   p_value
# 0          1.007895  0.770384
# 1          0.956116  0.744617
# 2          0.849286  0.321175
# 3          0.892232  0.358181
# 4          1.019286  0.953181

# %%
reliable["statistically_significant"] = reliable["p_value"] < 0.05

reliable.head()
# Out:
#   state_code income_bucket loan_purpose  applications_Female  \
# 0         AK          High            1                926.0
# 1         AK          High            2                130.0
# 2         AK          High           31                 56.0
# 3         AK          High           32                113.0
# 4         AK          High            4                127.0
#
#    applications_Male  approval_rate_Female  approval_rate_Male  \
# 0             1950.0              0.749460            0.743590
# 1              223.0              0.523077            0.547085
# 2              123.0              0.517857            0.609756
# 3              349.0              0.460177            0.515759
# 4              308.0              0.456693            0.448052
#
#    approvals_Female  approvals_Male  approval_gap_male_minus_female  \
# 0             694.0          1450.0                       -0.005870
# 1              68.0           122.0                        0.024008
# 2              29.0            75.0                        0.091899
# 3              52.0           180.0                        0.055582
# 4              58.0           138.0                       -0.008641
#
#    disparate_impact   p_value  statistically_significant
# 0          1.007895  0.770384                      False
# 1          0.956116  0.744617                      False
# 2          0.849286  0.321175                      False
# 3          0.892232  0.358181                      False
# 4          1.019286  0.953181                      False

# %%
reliable["statistically_significant"].value_counts()
# Out:
# statistically_significant
# False    461
# True     311
# Name: count, dtype: int64

# %%
significant = reliable[reliable["statistically_significant"]]

significant.shape
# Out:
# (311, 13)

# %%
significant["loan_purpose"].value_counts().sort_index()
# Out:
# loan_purpose
# 1     76
# 2     57
# 31    50
# 32    86
# 4     42
# Name: count, dtype: int64

# %%
significant["gap_direction"] = np.where(
    significant["approval_gap_male_minus_female"] > 0,
    "Male favored",
    "Female favored"
)

significant["gap_direction"].value_counts()
# Out:
# C:\Users\sonke\AppData\Local\Temp\ipykernel_4976\1305589209.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   significant["gap_direction"] = np.where(
# gap_direction
# Male favored      182
# Female favored    129
# Name: count, dtype: int64

# %%
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
